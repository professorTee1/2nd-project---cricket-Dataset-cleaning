# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb

# %%
df = pd.read_csv("./criket information.csv")
df
# Out:
#                  Player       Span  Mat  Inns    NO    Runs    HS    Ave  \
# 0      DG Bradman (AUS)  1928-1948   52    80  10.0  6996.0   334  99.94
# 1        AC Voges (AUS)  2015-2016   20    31   7.0  1485.0  269*  61.87
# 2   TT Samaraweera (SL)  2001-2013   81   132  20.0  5462.0   231  48.76
# 3       GA Headley (WI)  1930-1954   22    40   4.0  2190.0  270*  60.83
# 4     H Sutcliffe (ENG)  1924-1935   54    84   9.0  4555.0   194  60.73
# ..                  ...        ...  ...   ...   ...     ...   ...    ...
# 58    GC Smith (ICC/SA)  2002-2014  117   205  13.0  9265.0   277  48.25
# 59    WH Ponsford (AUS)  1924-1934   29    48   4.0  2122.0   266  48.22
# 60      SJ McCabe (AUS)  1930-1938   39    62   5.0  2748.0   232  48.21
# 61     DR Jardine (ENG)  1928-1934   22    33   6.0  1296.0   127  48.00
# 62    H Sutcliffe (ENG)  1924-1935   54    84   9.0  5478.0   194  60.73
#
#        BF     SR   100    50     0    4s  6s
# 0   9800+  58.60  29.0  13.0   7.0  626+   6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  63 non-null     object
#  1   Span    63 non-null     object
#  2   Mat     63 non-null     int64
#  3   Inns    63 non-null     int64
#  4   NO      62 non-null     float64
#  5   Runs    63 non-null     float64
#  6   HS      63 non-null     object
#  7   Ave     63 non-null     float64
#  8   BF      62 non-null     object
#  9   SR      63 non-null     float64
#  10  100     63 non-null     float64
#  11  50      63 non-null     float64
#  12  0       63 non-null     float64
#  13  4s      63 non-null     object
#  14  6s      63 non-null     object
# dtypes: float64(7), int64(2), object(6)
# memory usage: 7.5+ KB

# %%
df.isna().sum()
# Out:
# Player    0
# Span      0
# Mat       0
# Inns      0
# NO        1
# Runs      0
# HS        0
# Ave       0
# BF        1
# SR        0
# 100       0
# 50        0
# 0         0
# 4s        0
# 6s        0
# dtype: int64

# %%
df.head()
# Out:
#                 Player       Span  Mat  Inns    NO    Runs    HS    Ave  \
# 0     DG Bradman (AUS)  1928-1948   52    80  10.0  6996.0   334  99.94
# 1       AC Voges (AUS)  2015-2016   20    31   7.0  1485.0  269*  61.87
# 2  TT Samaraweera (SL)  2001-2013   81   132  20.0  5462.0   231  48.76
# 3      GA Headley (WI)  1930-1954   22    40   4.0  2190.0  270*  60.83
# 4    H Sutcliffe (ENG)  1924-1935   54    84   9.0  4555.0   194  60.73
#
#       BF     SR   100    50     0    4s 6s
# 0  9800+  58.60  29.0  13.0   7.0  626+  6
# 1   2667  55.68   5.0   4.0   2.0   186  5
# 2    NaN  46.92  14.0  30.0  11.0   633  7
# 3   416+  56.00  10.0   5.0   2.0  104+  1
# 4  6558+  34.59  16.0  23.0   2.0  202+  6

# %%
df = df.rename(columns={"Player" : "Player name", "Span" : "Playing span", "Mat" : "Matches played", "Inns":"Inning battled","NO" : "Not outs", "Runs":"Runs scored", "HS":"Highest inns scored", "Ave": "Batting average", "BF" : "Ball faced", "SR" : "Batting strike rate", "100" : "Upto Hundreds scored", "50" : "Upto Fifties scored", "0" :"Duck scored", "4s" : "Boundary fours", "6s" : "Boundary sixes"})

# %%
df.columns
# Out:
# Index(['Player name', 'Playing span', 'Matches played', 'Inning battled',
#        'Not outs', 'Runs scored', 'Highest inns scored', 'Batting average',
#        'Ball faced', 'Batting strike rate', 'Upto Hundreds scored',
#        'Upto Fifties scored', 'Duck scored', 'Boundary fours',
#        'Boundary sixes'],
#       dtype='object')

# %%
df[['Upto Fifties scored', 'Duck scored', 'Boundary fours']]
# Out:
#     Upto Fifties scored  Duck scored Boundary fours
# 0                  13.0          7.0           626+
# 1                   4.0          2.0            186
# 2                  30.0         11.0            633
# 3                   5.0          2.0           104+
# 4                  23.0          2.0           202+
# ..                  ...          ...            ...
# 58                 38.0         11.0           1165
# 59                  6.0          1.0           119+
# 60                 13.0          4.0           241+
# 61                 10.0          2.0            53+
# 62                 23.0          2.0           202+
#
# [63 rows x 3 columns]

# %%
df.head()
# Out:
#            Player name Playing span  Matches played  Inning battled  Not outs  \
# 0     DG Bradman (AUS)    1928-1948              52              80      10.0
# 1       AC Voges (AUS)    2015-2016              20              31       7.0
# 2  TT Samaraweera (SL)    2001-2013              81             132      20.0
# 3      GA Headley (WI)    1930-1954              22              40       4.0
# 4    H Sutcliffe (ENG)    1924-1935              54              84       9.0
#
#    Runs scored Highest inns scored  Batting average Ball faced  \
# 0       6996.0                 334            99.94      9800+
# 1       1485.0                269*            61.87       2667
# 2       5462.0                 231            48.76        NaN
# 3       2190.0                270*            60.83       416+
# 4       4555.0                 194            60.73      6558+
#
#    Batting strike rate  Upto Hundreds scored  Upto Fifties scored  \
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    63
# Name: count, dtype: int64

# %%
df = df.fillna(0)

# %%
df.isna().sum()
# Out:
# Player name             0
# Playing span            0
# Matches played          0
# Inning battled          0
# Not outs                0
# Runs scored             0
# Highest inns scored     0
# Batting average         0
# Ball faced              0
# Batting strike rate     0
# Upto Hundreds scored    0
# Upto Fifties scored     0
# Duck scored             0
# Boundary fours          0
# Boundary sixes          0
# dtype: int64

# %%
df
# Out:
#             Player name Playing span  Matches played  Inning battled  \
# 0      DG Bradman (AUS)    1928-1948              52              80
# 1        AC Voges (AUS)    2015-2016              20              31
# 2   TT Samaraweera (SL)    2001-2013              81             132
# 3       GA Headley (WI)    1930-1954              22              40
# 4     H Sutcliffe (ENG)    1924-1935              54              84
# ..                  ...          ...             ...             ...
# 58    GC Smith (ICC/SA)    2002-2014             117             205
# 59    WH Ponsford (AUS)    1924-1934              29              48
# 60      SJ McCabe (AUS)    1930-1938              39              62
# 61     DR Jardine (ENG)    1928-1934              22              33
# 62    H Sutcliffe (ENG)    1924-1935              54              84
#
#     Not outs  Runs scored Highest inns scored  Batting average Ball faced  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Player name           63 non-null     object
#  1   Playing span          63 non-null     object
#  2   Matches played        63 non-null     int64
#  3   Inning battled        63 non-null     int64
#  4   Not outs              63 non-null     float64
#  5   Runs scored           63 non-null     float64
#  6   Highest inns scored   63 non-null     object
#  7   Batting average       63 non-null     float64
#  8   Ball faced            63 non-null     object
#  9   Batting strike rate   63 non-null     float64
#  10  Upto Hundreds scored  63 non-null     float64
#  11  Upto Fifties scored   63 non-null     float64
#  12  Duck scored           63 non-null     float64
#  13  Boundary fours        63 non-null     object
#  14  Boundary sixes        63 non-null     object
# ...

# %%
df[["Start year", "End year"]] = df["Playing span"].str.split("-",n=1, expand= True)

# %%
df.head()
# Out:
#            Player name Playing span  Matches played  Inning battled  Not outs  \
# 0     DG Bradman (AUS)    1928-1948              52              80      10.0
# 1       AC Voges (AUS)    2015-2016              20              31       7.0
# 2  TT Samaraweera (SL)    2001-2013              81             132      20.0
# 3      GA Headley (WI)    1930-1954              22              40       4.0
# 4    H Sutcliffe (ENG)    1924-1935              54              84       9.0
#
#    Runs scored Highest inns scored  Batting average Ball faced  \
# 0       6996.0                 334            99.94      9800+
# 1       1485.0                269*            61.87       2667
# 2       5462.0                 231            48.76          0
# 3       2190.0                270*            60.83       416+
# 4       4555.0                 194            60.73      6558+
#
#    Batting strike rate  Upto Hundreds scored  Upto Fifties scored  \
# ...

# %%
df.drop(["Playing span"],axis= 1,inplace=True)
df
# Out:
#             Player name  Matches played  Inning battled  Not outs  \
# 0      DG Bradman (AUS)              52              80      10.0
# 1        AC Voges (AUS)              20              31       7.0
# 2   TT Samaraweera (SL)              81             132      20.0
# 3       GA Headley (WI)              22              40       4.0
# 4     H Sutcliffe (ENG)              54              84       9.0
# ..                  ...             ...             ...       ...
# 58    GC Smith (ICC/SA)             117             205      13.0
# 59    WH Ponsford (AUS)              29              48       4.0
# 60      SJ McCabe (AUS)              39              62       5.0
# 61     DR Jardine (ENG)              22              33       6.0
# 62    H Sutcliffe (ENG)              54              84       9.0
#
#     Runs scored Highest inns scored  Batting average Ball faced  \
# 0        6996.0                 334            99.94      9800+
# ...

# %%
df[["Player name", "Country"]]= df["Player name"].str.split("(", n=1, expand=True)

# %%
df.head()
# Out:
#        Player name  Matches played  Inning battled  Not outs  Runs scored  \
# 0      DG Bradman               52              80      10.0       6996.0
# 1        AC Voges               20              31       7.0       1485.0
# 2  TT Samaraweera               81             132      20.0       5462.0
# 3      GA Headley               22              40       4.0       2190.0
# 4     H Sutcliffe               54              84       9.0       4555.0
#
#   Highest inns scored  Batting average Ball faced  Batting strike rate  \
# 0                 334            99.94      9800+                58.60
# 1                269*            61.87       2667                55.68
# 2                 231            48.76          0                46.92
# 3                270*            60.83       416+                56.00
# 4                 194            60.73      6558+                34.59
#
#    Upto Hundreds scored  Upto Fifties scored  Duck scored Boundary fours  \
# ...

# %%
df["Country"] = df["Country"].str.strip(")")

# %%
df.duplicated().value_counts()
# Out:
# False    63
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        Player name  Matches played  Inning battled  Not outs  Runs scored  \
# 0      DG Bradman               52              80      10.0       6996.0
# 1        AC Voges               20              31       7.0       1485.0
# 2  TT Samaraweera               81             132      20.0       5462.0
# 3      GA Headley               22              40       4.0       2190.0
# 4     H Sutcliffe               54              84       9.0       4555.0
#
#   Highest inns scored  Batting average Ball faced  Batting strike rate  \
# 0                 334            99.94      9800+                58.60
# 1                269*            61.87       2667                55.68
# 2                 231            48.76          0                46.92
# 3                270*            60.83       416+                56.00
# 4                 194            60.73      6558+                34.59
#
#    Upto Hundreds scored  Upto Fifties scored  Duck scored Boundary fours  \
# ...

# %%
df["Start year"] = df["Start year"].astype(int)
df["End year"] = df["End year"].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Player name           63 non-null     object
#  1   Matches played        63 non-null     int64
#  2   Inning battled        63 non-null     int64
#  3   Not outs              63 non-null     float64
#  4   Runs scored           63 non-null     float64
#  5   Highest inns scored   63 non-null     object
#  6   Batting average       63 non-null     float64
#  7   Ball faced            63 non-null     object
#  8   Batting strike rate   63 non-null     float64
#  9   Upto Hundreds scored  63 non-null     float64
#  10  Upto Fifties scored   63 non-null     float64
#  11  Duck scored           63 non-null     float64
#  12  Boundary fours        63 non-null     object
#  13  Boundary sixes        63 non-null     object
#  14  Start year            63 non-null     int32
# ...

# %%
df["Career years"] = df["End year"] - df["Start year"]

# %%
df.head()
# Out:
#        Player name  Matches played  Inning battled  Not outs  Runs scored  \
# 0      DG Bradman               52              80      10.0       6996.0
# 1        AC Voges               20              31       7.0       1485.0
# 2  TT Samaraweera               81             132      20.0       5462.0
# 3      GA Headley               22              40       4.0       2190.0
# 4     H Sutcliffe               54              84       9.0       4555.0
#
#   Highest inns scored  Batting average Ball faced  Batting strike rate  \
# 0                 334            99.94      9800+                58.60
# 1                269*            61.87       2667                55.68
# 2                 231            48.76          0                46.92
# 3                270*            60.83       416+                56.00
# 4                 194            60.73      6558+                34.59
#
#    Upto Hundreds scored  Upto Fifties scored  Duck scored Boundary fours  \
# ...

# %%
df["Country"].value_counts()
# Out:
# Country
# AUS        16
# ENG        14
# WI          8
# SL          4
# IND         4
# SA          4
# PAK         4
# ICC/SA      2
# NZ          2
# ICC/IND     2
# ICC/WI      1
# ZIM         1
# ICC/PAK     1
# Name: count, dtype: int64

# %%
df["Country"] = df["Country"].str.strip("ICC/")
df["Country"].value_counts()
# Out:
# Country
# AUS    16
# ENG    14
# W       9
# SA      6
# ND      6
# PAK     5
# SL      4
# NZ      2
# ZIM     1
# Name: count, dtype: int64

# %%
df["Player country"] = df["Country"].replace({"AUS":"Australia","ENG":"England","W":"Washintom", "SA":"South africa", "ND":"India", "PAK": "Pakistan", "SL":"Srk linka", "NZ":"New zealand","ZIM":"Zimbabwe"})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Player name           63 non-null     object
#  1   Matches played        63 non-null     int64
#  2   Inning battled        63 non-null     int64
#  3   Not outs              63 non-null     float64
#  4   Runs scored           63 non-null     float64
#  5   Highest inns scored   63 non-null     object
#  6   Batting average       63 non-null     float64
#  7   Ball faced            63 non-null     object
#  8   Batting strike rate   63 non-null     float64
#  9   Upto Hundreds scored  63 non-null     float64
#  10  Upto Fifties scored   63 non-null     float64
#  11  Duck scored           63 non-null     float64
#  12  Boundary fours        63 non-null     object
#  13  Boundary sixes        63 non-null     object
#  14  Start year            63 non-null     int32
# ...

# %%
df
# Out:
#         Player name  Matches played  Inning battled  Not outs  Runs scored  \
# 0       DG Bradman               52              80      10.0       6996.0
# 1         AC Voges               20              31       7.0       1485.0
# 2   TT Samaraweera               81             132      20.0       5462.0
# 3       GA Headley               22              40       4.0       2190.0
# 4      H Sutcliffe               54              84       9.0       4555.0
# ..              ...             ...             ...       ...          ...
# 58        GC Smith              117             205      13.0       9265.0
# 59     WH Ponsford               29              48       4.0       2122.0
# 60       SJ McCabe               39              62       5.0       2748.0
# 61      DR Jardine               22              33       6.0       1296.0
# 62     H Sutcliffe               54              84       9.0       5478.0
#
# ...

# %%
df = df.drop(["Country"], axis=1)

# %%
df.head()
# Out:
#        Player name  Matches played  Inning battled  Not outs  Runs scored  \
# 0      DG Bradman               52              80      10.0       6996.0
# 1        AC Voges               20              31       7.0       1485.0
# 2  TT Samaraweera               81             132      20.0       5462.0
# 3      GA Headley               22              40       4.0       2190.0
# 4     H Sutcliffe               54              84       9.0       4555.0
#
#   Highest inns scored  Batting average Ball faced  Batting strike rate  \
# 0                 334            99.94      9800+                58.60
# 1                269*            61.87       2667                55.68
# 2                 231            48.76          0                46.92
# 3                270*            60.83       416+                56.00
# 4                 194            60.73      6558+                34.59
#
#    Upto Hundreds scored  Upto Fifties scored  Duck scored Boundary fours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Player name           63 non-null     object
#  1   Matches played        63 non-null     int64
#  2   Inning battled        63 non-null     int64
#  3   Not outs              63 non-null     float64
#  4   Runs scored           63 non-null     float64
#  5   Highest inns scored   63 non-null     object
#  6   Batting average       63 non-null     float64
#  7   Ball faced            63 non-null     object
#  8   Batting strike rate   63 non-null     float64
#  9   Upto Hundreds scored  63 non-null     float64
#  10  Upto Fifties scored   63 non-null     float64
#  11  Duck scored           63 non-null     float64
#  12  Boundary fours        63 non-null     object
#  13  Boundary sixes        63 non-null     object
#  14  Start year            63 non-null     int32
# ...

# %%
df["Highest inns scored"] = df["Highest inns scored"].str.strip("*")

df["Highest inns scored"] = df["Highest inns scored"].astype(int)

# %%
df["Ball faced"]
# Out:
# 0     9800+
# 1      2667
# 2         0
# 3      416+
# 4     6558+
#       ...
# 58    15525
# 59    3118+
# 60    3217+
# 61    2110+
# 62    6558+
# Name: Ball faced, Length: 63, dtype: object

# %%
df["Ball faced"] = df["Ball faced"].str.strip("+")

# %%
df["Ball faced"]
# Out:
# 0      9800
# 1      2667
# 2       NaN
# 3       416
# 4      6558
#       ...
# 58    15525
# 59     3118
# 60     3217
# 61     2110
# 62     6558
# Name: Ball faced, Length: 63, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Player name           63 non-null     object
#  1   Matches played        63 non-null     int64
#  2   Inning battled        63 non-null     int64
#  3   Not outs              63 non-null     float64
#  4   Runs scored           63 non-null     float64
#  5   Highest inns scored   63 non-null     int32
#  6   Batting average       63 non-null     float64
#  7   Ball faced            62 non-null     object
#  8   Batting strike rate   63 non-null     float64
#  9   Upto Hundreds scored  63 non-null     float64
#  10  Upto Fifties scored   63 non-null     float64
#  11  Duck scored           63 non-null     float64
#  12  Boundary fours        63 non-null     object
#  13  Boundary sixes        63 non-null     object
#  14  Start year            63 non-null     int32
# ...

# %%
df["Ball faced"].isna().value_counts()
# Out:
# Ball faced
# False    62
# True      1
# Name: count, dtype: int64

# %%
df["Ball faced"] = df["Ball faced"].fillna(0)

# %%
df.head()
# Out:
#        Player name  Matches played  Inning battled  Not outs  Runs scored  \
# 0      DG Bradman               52              80      10.0       6996.0
# 1        AC Voges               20              31       7.0       1485.0
# 2  TT Samaraweera               81             132      20.0       5462.0
# 3      GA Headley               22              40       4.0       2190.0
# 4     H Sutcliffe               54              84       9.0       4555.0
#
#    Highest inns scored  Batting average Ball faced  Batting strike rate  \
# 0                  334            99.94       9800                58.60
# 1                  269            61.87       2667                55.68
# 2                  231            48.76          0                46.92
# 3                  270            60.83        416                56.00
# 4                  194            60.73       6558                34.59
#
#    Upto Hundreds scored  Upto Fifties scored  Duck scored Boundary fours  \
# ...

# %%
df["Ball faced"] = df["Ball faced"].str.strip("-")

# %%
df["Ball faced"]
# Out:
# 0      9800
# 1      2667
# 2       NaN
# 3       416
# 4      6558
#       ...
# 58    15525
# 59     3118
# 60     3217
# 61     2110
# 62     6558
# Name: Ball faced, Length: 63, dtype: object

# %%
df["Ball faced"] = df["Ball faced"].str.strip()

# %%
pd.to_numeric(df["Ball faced"], errors="coerce")
# Out:
# 0      9800.0
# 1      2667.0
# 2         NaN
# 3       416.0
# 4      6558.0
#        ...
# 58    15525.0
# 59     3118.0
# 60     3217.0
# 61     2110.0
# 62     6558.0
# Name: Ball faced, Length: 63, dtype: float64

# %%
df[df["Ball faced"] == '']
# Out:
#         Player name  Matches played  Inning battled  Not outs  Runs scored  \
# 8        ED Weekes               48              81       5.0       4455.0
# 14      CL Walcott               44              74       7.0       3798.0
# 54  Hon.FS Jackson               20              33       4.0       1415.0
#
#     Highest inns scored  Batting average Ball faced  Batting strike rate  \
# 8                   207            58.61                             0.0
# 14                  220            56.68                             0.0
# 54                  144            48.79                             0.0
#
#     Upto Hundreds scored  Upto Fifties scored  Duck scored Boundary fours  \
# 8                   15.0                 19.0          6.0           258+
# 14                  15.0                 14.0          1.0           107+
# 54                   5.0                  6.0          3.0            51+
#
#    Boundary sixes  Start year  End year  Career years Player country
# ...

# %%
df["Ball faced"] = df["Ball faced"].replace({'': 0})

# %%
df["Ball faced"]
# Out:
# 0      9800
# 1      2667
# 2       NaN
# 3       416
# 4      6558
#       ...
# 58    15525
# 59     3118
# 60     3217
# 61     2110
# 62     6558
# Name: Ball faced, Length: 63, dtype: object

# %%
df[df["Ball faced"] == 0]
# Out:
#         Player name  Matches played  Inning battled  Not outs  Runs scored  \
# 8        ED Weekes               48              81       5.0       4455.0
# 14      CL Walcott               44              74       7.0       3798.0
# 54  Hon.FS Jackson               20              33       4.0       1415.0
#
#     Highest inns scored  Batting average Ball faced  Batting strike rate  \
# 8                   207            58.61          0                  0.0
# 14                  220            56.68          0                  0.0
# 54                  144            48.79          0                  0.0
#
#     Upto Hundreds scored  Upto Fifties scored  Duck scored Boundary fours  \
# 8                   15.0                 19.0          6.0           258+
# 14                  15.0                 14.0          1.0           107+
# 54                   5.0                  6.0          3.0            51+
#
#    Boundary sixes  Start year  End year  Career years Player country
# ...

# %%
df["Ball faced"] = df["Ball faced"].fillna(0)

# %%
df["Boundary fours"] = df["Boundary fours"].str.strip("+")

# %%
df["Boundary sixes"] = df["Boundary sixes"].str.strip("+")

# %%
df["Ball faced"] = df["Ball faced"].astype(int)
df["Runs scored"] = df["Runs scored"].astype(int)
df["Not outs"] = df["Not outs"].astype(int)
df["Upto Hundreds scored"] = df["Upto Hundreds scored"].astype(int)
df["Upto Fifties scored"] = df["Upto Fifties scored"].astype(int)
df["Duck scored"] = df["Duck scored"].astype(int)
df["Boundary fours"] = df["Boundary fours"].astype(int)
df["Boundary sixes"] = df["Boundary sixes"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Player name           63 non-null     object
#  1   Matches played        63 non-null     int64
#  2   Inning battled        63 non-null     int64
#  3   Not outs              63 non-null     int32
#  4   Runs scored           63 non-null     int32
#  5   Highest inns scored   63 non-null     int32
#  6   Batting average       63 non-null     float64
#  7   Ball faced            62 non-null     object
#  8   Batting strike rate   63 non-null     float64
#  9   Upto Hundreds scored  63 non-null     int32
#  10  Upto Fifties scored   63 non-null     int32
#  11  Duck scored           63 non-null     int32
#  12  Boundary fours        63 non-null     int32
#  13  Boundary sixes        63 non-null     int32
#  14  Start year            63 non-null     int32
# ...

# %%
df.head()
# Out:
#        Player name  Matches played  Inning battled  Not outs  Runs scored  \
# 0      DG Bradman               52              80        10         6996
# 1        AC Voges               20              31         7         1485
# 2  TT Samaraweera               81             132        20         5462
# 3      GA Headley               22              40         4         2190
# 4     H Sutcliffe               54              84         9         4555
#
#    Highest inns scored  Batting average  Ball faced  Batting strike rate  \
# 0                  334            99.94        9800                58.60
# 1                  269            61.87        2667                55.68
# 2                  231            48.76           0                46.92
# 3                  270            60.83         416                56.00
# 4                  194            60.73        6558                34.59
#
#    Upto Hundreds scored  Upto Fifties scored  Duck scored  Boundary fours  \
# ...

# %%
df["Runs scored"].plot(kind= 'box')
# Out:
# <Axes: >

# %%
dff = df.groupby("Player country")["Matches played"].count()
dff
# Out:
# Player country
# Australia       16
# England         14
# India            6
# New zealand      2
# Pakistan         5
# South africa     6
# Srk linka        4
# Washintom        9
# Zimbabwe         1
# Name: Matches played, dtype: int64

# %%
df.groupby("Player name")["Career years"].sum().sort_values(ascending = False)[0:10].to_frame()
# Out:
#                  Career years
# Player name
# GA Headley                 24
# TT Samaraweera             24
# SR Tendulkar               24
# JB Hobbs                   22
# H Sutcliffe                22
# S Chanderpaul              21
# DG Bradman                 20
# DCS Compton                20
# GS Sobers                  20
# B Mitchell                 20

# %%
df.head()
# Out:
#        Player name  Matches played  Inning battled  Not outs  Runs scored  \
# 0      DG Bradman               52              80        10         6996
# 1        AC Voges               20              31         7         1485
# 2  TT Samaraweera               81             132        20         5462
# 3      GA Headley               22              40         4         2190
# 4     H Sutcliffe               54              84         9         4555
#
#    Highest inns scored  Batting average  Ball faced  Batting strike rate  \
# 0                  334            99.94        9800                58.60
# 1                  269            61.87        2667                55.68
# 2                  231            48.76           0                46.92
# 3                  270            60.83         416                56.00
# 4                  194            60.73        6558                34.59
#
#    Upto Hundreds scored  Upto Fifties scored  Duck scored  Boundary fours  \
# ...

# %%
df.groupby("Player country")["Career years"].mean()
# Out:
# Player country
# Australia       12.437500
# England         12.857143
# India           13.833333
# New zealand      9.500000
# Pakistan        12.600000
# South africa    14.166667
# Srk linka       14.000000
# Washintom       15.555556
# Zimbabwe        10.000000
# Name: Career years, dtype: float64

# %%
dfff= df.groupby("Player country")["Player name"].count()
dfff
# Out:
# Player country
# Australia       16
# England         14
# India            6
# New zealand      2
# Pakistan         5
# South africa     6
# Srk linka        4
# Washintom        9
# Zimbabwe         1
# Name: Player name, dtype: int64

# %%
dfff.plot(kind= "barh", color="red")
plt.title("COUNTRY WITH THE HIGHEST PLAYER")
plt.show()

# %%
sb.scatterplot(x=df["Highest inns scored"], y=df["Player country"])
# Out:
# <Axes: xlabel='Highest inns scored', ylabel='Player country'>

# %%
df.head()
# Out:
#        Player name  Matches played  Inning battled  Not outs  Runs scored  \
# 0      DG Bradman               52              80        10         6996
# 1        AC Voges               20              31         7         1485
# 2  TT Samaraweera               81             132        20         5462
# 3      GA Headley               22              40         4         2190
# 4     H Sutcliffe               54              84         9         4555
#
#    Highest inns scored  Batting average  Ball faced  Batting strike rate  \
# 0                  334            99.94        9800                58.60
# 1                  269            61.87        2667                55.68
# 2                  231            48.76           0                46.92
# 3                  270            60.83         416                56.00
# 4                  194            60.73        6558                34.59
#
#    Upto Hundreds scored  Upto Fifties scored  Duck scored  Boundary fours  \
# ...

# %%
df["Career years"].mean()
# Out:
# 13.253968253968255

# %%
df.groupby("Career years")["Batting strike rate"].agg([np.sum,np.max,np.mean,'count'])
# Out:
#                  sum   amax       mean  count
# Career years
# 1              55.68  55.68  55.680000      1
# 2             198.37  90.65  66.123333      3
# 5             126.57  53.35  42.190000      3
# 6              78.27  52.68  39.135000      2
# 8             185.24  60.02  46.310000      4
# 9              44.86  44.86  44.860000      1
# 10             89.84  45.07  29.946667      3
# 11            125.10  55.92  41.700000      3
# 12            344.84  82.23  43.105000      8
# 13             97.98  55.56  48.990000      2
# 14            210.95  54.51  52.737500      4
# 15            252.21  60.10  50.442000      5
# 16            300.50  63.88  50.083333      6
# 17            308.09  69.77  51.348333      6
# 18             85.31  45.97  42.655000      2
# 19             48.64  48.64  48.640000      1
# 20            218.17  58.60  43.634000      5
# 21             43.31  43.31  43.310000      1
# 22             46.22  46.22  46.220000      1
# ...

# %%
df[df["Career years"]> 10]["Batting strike rate"]
# Out:
# 0     58.60
# 2     46.92
# 3     56.00
# 4     34.59
# 7     42.42
# 9     38.07
# 10    53.58
# 11    54.19
# 12    53.50
# 13    46.22
# 14     0.00
# 15    39.34
# 16    45.97
# 18    51.41
# 21    51.53
# 22    63.88
# 23    54.04
# 24    60.51
# 25    45.99
# 26    42.51
# 27    52.39
# 28    52.12
# 29    58.72
# 33    43.31
# 34    43.35
# 35    48.64
# 36    60.10
# 37    54.51
# 38    41.09
# 40    69.77
# 41    56.71
# 42    38.81
# 43    51.45
# 44    54.02
# 46    40.16
# 47    30.04
# 48    82.23
# 50    55.56
# 51    55.92
# 53    29.11
# 54     0.00
# 55    46.92
# 56    43.74
# 57    49.16
# 58    59.67
# 62    34.59
# Name: Batting strike rate, dtype: float64

# %%
df[df["Career years"]> 10]["Batting strike rate"].mean()
# Out:
# 47.63826086956522

# %%
df[df["Start year"] < 1960]["Player name"].count()
# Out:
# 24

# %%
df[df["Start year"] < 1960]["Player name"]
# Out:
# 0         DG Bradman
# 3         GA Headley
# 4        H Sutcliffe
# 6          E Paynter
# 7      KF Barrington
# 8          ED Weekes
# 9         WR Hammond
# 10         GS Sobers
# 13          JB Hobbs
# 14        CL Walcott
# 15          L Hutton
# 17      GE Tyldesley
# 22         AD Nourse
# 30           J Ryder
# 42       DCS Compton
# 46       FMM Worrell
# 47           CP Mead
# 53        B Mitchell
# 54    Hon.FS Jackson
# 56         RN Harvey
# 59       WH Ponsford
# 60         SJ McCabe
# 61        DR Jardine
# 62       H Sutcliffe
# Name: Player name, dtype: object

# %%
df.groupby("Player country")["Highest inns scored"].agg([np.max, np.min, np. mean, np.sum])
# Out:
#                 amax  amin        mean   sum
# Player country
# Australia        380   195  251.500000  4024
# England          364   122  220.785714  3091
# India            319   227  259.000000  1554
# New zealand      251   190  220.500000   441
# Pakistan         329   215  272.000000  1360
# South africa     278   144  223.833333  1343
# Srk linka        374   231  288.750000  1155
# Washintom        400   183  266.666667  2400
# Zimbabwe         232   232  232.000000   232

# %%
df.groupby("Player country")[["Upto Hundreds scored", "Upto Fifties scored","Duck scored"]].agg([np.max, np.min, np. mean, np.sum]).sort_values(by="Player country")
# Out:
#                Upto Hundreds scored                      Upto Fifties scored  \
#                                amax amin       mean  sum                amax
# Player country
# Australia                        41    3  20.625000  330                  63
# England                          32    1  12.785714  179                  63
# India                            51    4  29.500000  177                  68
# New zealand                      32    5  18.500000   37                  34
# Pakistan                         34    4  22.000000  110                  46
# South africa                     45    3  19.000000  114                  58
# Srk linka                        38   14  25.000000  100                  52
# Washintom                        34    4  18.555556  167                  66
# Zimbabwe                         12   12  12.000000   12                  27
#
#                                     Duck scored
# ...

# %%
df.groupby("Player country")[["Upto Hundreds scored", "Upto Fifties scored","Duck scored"]].agg([np.max, np.min, np. mean, np.sum]).plot(kind="barh")
# Out:
# <Axes: ylabel='Player country'>

# %%
df.to_csv("properly cleaned criket file.csv", index=False)

# %%
df =  pd.read_csv("./properly cleaned criket file.csv")
df
# Out:
#         Player name  Matches played  Inning battled  Not outs  Runs scored  \
# 0       DG Bradman               52              80        10         6996
# 1         AC Voges               20              31         7         1485
# 2   TT Samaraweera               81             132        20         5462
# 3       GA Headley               22              40         4         2190
# 4      H Sutcliffe               54              84         9         4555
# ..              ...             ...             ...       ...          ...
# 58        GC Smith              117             205        13         9265
# 59     WH Ponsford               29              48         4         2122
# 60       SJ McCabe               39              62         5         2748
# 61      DR Jardine               22              33         6         1296
# 62     H Sutcliffe               54              84         9         5478
#
# ...

# %%
df =  pd.read_excel("./properly cleaned criket file.xlsx", index_col=0)
df
# Out:
#         Player name  Matches played  Inning battled  Not outs  Runs scored  \
# 0       DG Bradman               52              80        10         6996
# 1         AC Voges               20              31         7         1485
# 2   TT Samaraweera               81             132        20         5462
# 3       GA Headley               22              40         4         2190
# 4      H Sutcliffe               54              84         9         4555
# ..              ...             ...             ...       ...          ...
# 58        GC Smith              117             205        13         9265
# 59     WH Ponsford               29              48         4         2122
# 60       SJ McCabe               39              62         5         2748
# 61      DR Jardine               22              33         6         1296
# 62     H Sutcliffe               54              84         9         5478
#
# ...

# %%
#df.reset_index(drop=True, inplace=True)
#df.head()
